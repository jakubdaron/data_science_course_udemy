# %% [markdown]
# <a href="https://colab.research.google.com/github/jakubdaron/data_science_course_udemy/blob/main/Prawdopodobienstwo_i_Statystyka/01_p_stwo_statystyka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lekkie** **wprowadzenie**

# %% [markdown]
# Przykład - dane dyskretne,
# Populacja - grupa studentów (5 osób),
# Badana cecha - ocena,
# Realizacja zmiennej: 3, 4.5, 5, 4.5, 3

# %%
import numpy as np
X = np.array([3, 4.5, 5, 4.5, 3])
print(X)
# Out:
# [3.  4.5 5.  4.5 3. ]

# %% [markdown]
# **Statystyka opisowa - miary tendencji centralnej**

# %% [markdown]
# Średnia

# %%
X.mean()
# Out:
# 4.0

# %% [markdown]
# Mediana

# %%
np.median(X)
# Out:
# 4.5

# %% [markdown]
# Moda

# %% [markdown]
# **Statystyka opisowa - miary rozrzutu**

# %% [markdown]
# średni błąd

# %%
X = [3.5, 4.0, 4.0]
Y = [2.0, 4.0, 5.0]

X_mean = np.mean(X)
Y_mean = np.mean(Y)

print(f"X_mean: {X_mean: .4f}")
print(f"Y_mean: {Y_mean: .4f}")
# Out:
# X_mean:  3.8333
# Y_mean:  3.6667

# %%
b_X = 1 / len(X) * (abs(X - X_mean).sum())
b_Y = 1 / len(Y) * (abs(Y - Y_mean).sum())

print(f"Średni bład X: {b_X: .4f}")
print(f"Średni bład Y: {b_Y: .4f}")
# Out:
# Średni bład X:  0.2222
# Średni bład Y:  1.1111

# %% [markdown]
# Wariancja i odchylenie standardowe

# %%
var_X = 1 / len(X) * ((X - X_mean)**2).sum()
var_Y = 1 / len(Y) * ((Y - Y_mean)**2).sum()

print(f"Wariancja zmiennej X: {var_X: .4f}")
print(f"Wariancja zmiennej Y: {var_Y: .4f}")

std_X = np.sqrt(var_X)
std_Y = np.sqrt(var_Y)

print(f'Odchylenie standardowe zmiennej X: {std_X: .4f}')
print(f'Odchylenie standardowe zmiennej Y: {std_Y: .4f}')
# Out:
# Wariancja zmiennej X:  0.0556
# Wariancja zmiennej Y:  1.5556
# Odchylenie standardowe zmiennej X:  0.2357
# Odchylenie standardowe zmiennej Y:  1.2472

# %%
print(np.std(X))
print(np.std(Y))
# Out:
# 0.23570226039551584
# 1.247219128924647

# %% [markdown]
# Dystrybuanta empiryczna

# %% [markdown]
# Przestrzeń probabilistyczna

# %% [markdown]
# Przestrzeń klasyczna

# %%
omega = {1, 2, 3, 4, 5, 6}
A = {item for item in omega if item % 2 == 0}
B = {item for item in omega if item > 4}

P_A = len(A) / len(omega)
P_B = len(B) / len(omega)
print(f'Zbiór A: {A}')
print(f'Prawdopodobieństwo zdarzenia A: {P_A:.4f}')
# Out:
# Zbiór A: {2, 4, 6}
# Prawdopodobieństwo zdarzenia A: 0.5000

# %% [markdown]
# Niezależność zdarzeń

# %%
intersection_AB = set.intersection(A, B)
P_intersection_AB = len(intersection_AB) / len(omega)

PA_PB = P_A * P_B

print(f'Przecięcie zbiorów A i B: {intersection_AB}\n')
print(f'Iloczyn prawdopodobieńśtw zdarzeń A i B: {PA_PB:.4f}')
print(f'Prawdopodobieństwo iloczynu zdarzeń A i B: {P_intersection_AB:.4f}\n')

check = 'Zdarzenia niezależne' if PA_PB == P_intersection_AB else 'Zdarzenia zależne'
print(check)
# Out:
# Przecięcie zbiorów A i B: {6}
#
# Iloczyn prawdopodobieńśtw zdarzeń A i B: 0.1667
# Prawdopodobieństwo iloczynu zdarzeń A i B: 0.1667
#
# Zdarzenia niezależne

# %% [markdown]
# Prawdopodobieństwo warunkowe

# %%
PA_cond_B = P_intersection_AB / P_B

print(f'Prawdopodobieństwo wylosowania liczby parzystej pod warunkiem, że wylosowalismy liczbę większą niż 4 wynosi: {PA_cond_B:.4f}')
# Out:
# Prawdopodobieństwo wylosowania liczby parzystej pod warunkiem, że wylosowalismy liczbę większą niż 4 wynosi: 0.5000

# %% [markdown]
# **Zmienna losowa**

# %% [markdown]
# Dystrybuanta

# %% [markdown]
# Wartość oczekiwana

# %% [markdown]
# Wariancja

# %% [markdown]
# Odchylenie standardowe

# %% [markdown]
# Kowariancja

# %% [markdown]
# Korelacja

# %% [markdown]
# Błąd standardowy

# %% [markdown]
# Przykład 1

# %%
# wartosc oczekiwana
EX = 0 * 0.5 + 1 * 0.3 + 2 * 0.15 + 3 * 0.05
EX
# Out:
# 0.75

# %%
# wariancja
VAR_X = (0-EX)**2 * 0.5 + (1-EX)**2 * 0.3 + (2-EX)**2 * 0.15 + (3-EX)**2 * 0.05
VAR_X
# Out:
# 0.7875000000000001

# %%
import numpy as np

STD_X = np.sqrt(VAR_X)
STD_X
# Out:
# 0.8874119674649424

# %% [markdown]
# Przykład 2

# %%
x = np.random.randn(5)
y = np.random.randn(5)

print(x)
print(y)
# Out:
# [-0.91641589 -2.26911866  0.40831568 -0.50952771 -0.02116884]
# [-0.67212105 -0.35569607 -0.56111562  0.79192702 -1.82410546]

# %%
x.mean()
# Out:
# -0.6615830842877934

# %%
x.std()
# Out:
# 0.9194612564650902

# %%
np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.23618707],
#        [-0.23618707,  1.        ]])

# %% [markdown]
# Rozkład normalny

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
sns.set()

mu = 0 # średnia
sigma = 1 # odchylenie standardowe
x = np.linspace(mu - 3 * sigma, mu + 3 * sigma, 100)
plt.title("Rozkład normalny - funkcja gęstości")
_ = plt.plot(x, norm.pdf(x, mu, sigma))

# %%
x = np.linspace(mu - 3 * sigma, mu + 3 * sigma, 500)
params = [(0, 1), (0, 2), (0, 0.5)]

plt.figure(figsize=(8, 8))
for mu, sigma in params:
  plt.plot(x, norm.pdf(x, mu, sigma), label=f'mu={mu}, sigma={sigma}')
plt.legend()

# %% [markdown]
# Standaryzacja

# %%
mu = 10
sigma = 3
x = np.linspace(mu - 8 * sigma, mu + 8 * sigma, 500)

plt.plot(x, norm.pdf(x, mu, sigma), label=f'mu={mu}, sigma={sigma}')

plt.plot(x, norm.pdf(x, mu - mu, sigma), label=f'mu={mu - mu}, sigma={sigma}')
plt.plot(x, norm.pdf(x, mu - mu, sigma / sigma), label=f'mu={mu - mu}, sigma={sigma / sigma}')
plt.legend()

# %% [markdown]
# Wykres dystrybuanty

# %%
plt.title('Rozkład normalny - dystrybuanta')
_ = plt.plot(x, norm.cdf(x, mu, sigma))

# %%
plt.title('Rozkład normalny - funkcja przeżycia')
_ = plt.plot(x, norm.sf(x, mu, sigma))
